# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
URL = 'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/building_inventory.csv'
df = pd.read_csv(URL)
df.shape
# Out:
# (8862, 22)

# %%
df_filter = df[(df['Square Footage'] == 0)| (df['Year Constructed'] == 0)]
df_filter.index
# Out:
# Index([  74,   76,  181,  225,  226,  227,  231,  232,  233,  234,
#        ...
#        8840, 8841, 8842, 8843, 8844, 8847, 8855, 8856, 8857, 8858],
#       dtype='int64', length=314)

# %%
df_1 = df.drop(df.index[df_filter.index])

# %%
df_2 = df[(df['City'] == 'Champaign') | (df['City'] == 'Urbana') | (df['City'] == 'Savoy') | (df['City'] == 'Monticello')| (df['City'] == 'Rantoul')]
df_2.head()
# Out:
#                 Agency Name                            Location Name  \
# 340  University of Illinois  University of Illinois Urbana-Champaign
# 341  University of Illinois  University of Illinois Urbana-Champaign
# 342  University of Illinois  University of Illinois Urbana-Champaign
# 343  University of Illinois  University of Illinois Urbana-Champaign
# 344  University of Illinois  University of Illinois Urbana-Champaign
#
#                        Address       City  Zip code     County  Congress Dist  \
# 340      1301 South Oak Street  Champaign     61820  Champaign             13
# 341  2301 South Lincoln Avenue     Urbana     61820  Champaign             13
# 342  2301 South Lincoln Avenue     Urbana     61820  Champaign             13
# 343  2301 South Lincoln Avenue     Urbana     61820  Champaign             13
# 344          South Race Street     Urbana     61820  Champaign             13
#
#     Congressional Full Name  Rep Dist Rep Full Name  ...  Bldg Status  \
# ...

# %%
pivot_df = pd.pivot_table(df_2, index='City', columns='Bldg Status', aggfunc='size', fill_value=0)
pivot_df = pivot_df.reset_index()
pivot_df
# Out:
# Bldg Status        City  Abandon  In Progress  In Use
# 0             Champaign        0            1     148
# 1            Monticello        0            0       9
# 2               Rantoul        6            4       0
# 3                 Savoy        0            0      32
# 4                Urbana        0            2     202

# %%
df_2.to_csv('bstatus.csv', index=False)
